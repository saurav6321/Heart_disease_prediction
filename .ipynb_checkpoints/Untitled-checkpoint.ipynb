# %%
#importing the module
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.cm import rainbow
from matplotlib.cm import rainbow
from sklearn.model_selection import train_test_split

# %%
#importing the dataset
data=pd.read_csv('framingham.csv')
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# 1                   0             0         0    250.0  121.0   81.0  28.73
# 2                   0             0         0    245.0  127.5   80.0  25.34
# 3                   0             1         0    225.0  150.0   95.0  28.58
# 4                   0             0         0    285.0  130.0   84.0  23.10
# ...               ...           ...       ...      ...    ...    ...    ...
# 4235                0             0         0    248.0  131.0   72.0  22.00
# 4236                0             0         0    210.0  126.5   87.0  19.16
# 4237                0             0         0    269.0  133.5   83.0  21.47
# 4238                0             1         0    185.0  141.0   98.0  25.60
# 4239                0             0         0    196.0  133.0   86.0  20.91
#
#       heartRate  glucose  TenYearCHD
# 0          80.0     77.0           0
# 1          95.0     76.0           0
# 2          75.0     70.0           0
# 3          65.0    103.0           1
# 4          85.0     85.0           0
# ...         ...      ...         ...
# 4235       84.0     86.0           0
# 4236       86.0      NaN           0
# 4237       80.0    107.0           0
# 4238       67.0     72.0           0
# 4239       85.0     80.0           0
#
# [4240 rows x 16 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# memory usage: 530.1 KB

# %%
data.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# min       0.000000         0.000000      0.000000     0.000000   107.000000
# 25%       0.000000         0.000000      0.000000     0.000000   206.000000
# 50%       0.000000         0.000000      0.000000     0.000000   234.000000
# 75%       0.000000         0.000000      1.000000     0.000000   263.000000
# max       1.000000         1.000000      1.000000     1.000000   696.000000
#
#              sysBP        diaBP          BMI    heartRate      glucose  \
# count  4240.000000  4240.000000  4221.000000  4239.000000  3852.000000
# mean    132.354599    82.897759    25.800801    75.878981    81.963655
# std      22.033300    11.910394     4.079840    12.025348    23.954335
# min      83.500000    48.000000    15.540000    44.000000    40.000000
# 25%     117.000000    75.000000    23.070000    68.000000    71.000000
# 50%     128.000000    82.000000    25.400000    75.000000    78.000000
# 75%     144.000000    90.000000    28.040000    83.000000    87.000000
# max     295.000000   142.500000    56.800000   143.000000   394.000000
#
#         TenYearCHD
# count  4240.000000
# mean      0.151887
# std       0.358953
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %% [markdown]
# ## Feature Selection

# %%
import seaborn as sns
#checking corelation between each feature using corr function
cormat=data.corr()
top_corr_features=cormat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87ACB108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB886B8D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87C16C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87C4FDC8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87C89EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87CC0F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87CFE108>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87D36208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87D3DD88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87D76F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87DE04C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB8861E5C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87E28708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87E5F808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87E98908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BB87ED3A48>]],
#       dtype=object)

# %% [markdown]
# # splitting dataset

# %%
#Create independent and Dependent Features
columns = data.columns.tolist()
# Filter the columns to remove data we do not want 
columns = [c for c in columns if c not in ["TenYearCHD"]]
# Store the variable we are predicting 
target = "TenYearCHD"
# Define a random state 
state = np.random.RandomState(42)
x= data[columns]
y = data[target]
# Print the shapes of X & Y
print(x.shape)
print(y.shape)
# Out:
# (4240, 15)
# (4240,)

# %% [markdown]
# # filling up null values

# %%
x.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# dtype: int64

# %%
y.isnull().sum()
# Out:
# 0

# %%
x['cigsPerDay'].fillna(x.groupby('currentSmoker')['cigsPerDay'].transform('mean'),inplace=True)
x['BPMeds'].fillna(x.groupby('prevalentHyp')['BPMeds'].transform('median'),inplace=True)
x['totChol'].fillna(x.groupby('prevalentStroke')['totChol'].transform('mean'),inplace=True)
x['BMI'].fillna(x.groupby('age')['BMI'].transform('mean'),inplace=True)
x['heartRate'].fillna(x.groupby('sysBP')['heartRate'].transform('mean'),inplace=True)
x['glucose'].fillna(x.groupby('diabetes')['glucose'].transform('mean'),inplace=True)
x['education'].fillna(x.groupby('age')['education'].transform('mean'),inplace=True)
# Out:
# C:\Users\saurav aditya\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
x.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# dtype: int64

# %% [markdown]
# # Balance Dataset

# %%
sns.set_style('whitegrid')
sns.countplot(x ='TenYearCHD',data=data,palette='RdBu_r')

# %%
disease= data[data['TenYearCHD']==1]
no= data[data['TenYearCHD']==0]
print(disease.shape,no.shape)
# Out:
# (644, 16) (3596, 16)

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss

# %%
smk=SMOTETomek(random_state=42)
x_res,y_res=smk.fit_resample(x,y)
x_res.shape,y_res.shape
# Out:
# ((7138, 15), (7138,))

# %%
from collections import Counter
print('original data {}'.format(Counter(y)))
print('Resampled data {}'.format(Counter(y_res)))
# Out:
# original data Counter({0: 3596, 1: 644})
# Resampled data Counter({0: 3569, 1: 3569})

# %%
from sklearn.preprocessing import StandardScaler
standardScaler = StandardScaler()
columns_to_scale =['age','BPMeds','cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose']
x_res[columns_to_scale] = standardScaler.fit_transform(x_res[columns_to_scale])

# %%
x_res
# Out:
#       male       age  education  currentSmoker  cigsPerDay    BPMeds  \
# 0        1 -1.491940   4.000000              0   -0.802371 -0.235345
# 1        0 -0.636581   2.000000              0   -0.802371 -0.235345
# 2        1 -0.392192   1.000000              1    0.872022 -0.235345
# 3        0  1.196332   3.000000              1    1.709218 -0.235345
# 4        0 -0.636581   3.000000              1    1.123181 -0.235345
# ...    ...       ...        ...            ...         ...       ...
# 7133     1 -0.392192   3.073740              1    0.293313 -0.235345
# 7134     0  0.829749   1.000000              0   -0.802371 -0.235345
# 7135     1 -1.491940   3.379383              1    0.583318 -0.235345
# 7136     0  0.585361   1.000000              0   -0.802371 -0.235345
# 7137     0  0.707555   2.000000              0   -0.802371 -0.235345
#
#       prevalentStroke  prevalentHyp  diabetes   totChol     sysBP     diaBP  \
# 0                   0             0         0 -0.999691 -1.291367 -1.176209
# 1                   0             0         0  0.232903 -0.656801 -0.288288
# 2                   0             0         0  0.120849 -0.381822 -0.369008
# 3                   0             1         0 -0.327367  0.570027  0.841794
# 4                   0             0         0  1.017282 -0.276061 -0.046127
# ...               ...           ...       ...       ...       ...       ...
# 7133                0             0         0 -1.258396 -0.409213  0.209051
# 7134                0             1         0  0.990995  2.487447 -0.798353
# 7135                0             0         0 -0.142674 -0.753098 -0.686355
# 7136                0             0         0  0.076328 -0.762986 -0.812159
# 7137                0             1         0  1.051783  2.265968  2.056188
#
#            BMI  heartRate   glucose
# 0     0.226256   0.338382 -0.241270
# 1     0.670725   1.636868 -0.273778
# 2    -0.185383  -0.094446 -0.468828
# 3     0.632844  -0.960104  0.603947
# 4    -0.751072   0.771211  0.018797
# ...        ...        ...       ...
# 7133  0.672065  -1.498648 -0.273330
# 7134  0.051262  -0.381285 -0.176078
# 7135  1.117537   0.935419  0.447036
# 7136 -0.218306  -1.175070 -0.080033
# 7137  0.026050   0.617241 -0.020329
#
# [7138 rows x 15 columns]

# %%
x_res.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# dtype: int64

# %% [markdown]
# # Different Classifiers

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
X=x_res.drop(['education','currentSmoker'],axis=1)
Y=y_res
X
# Out:
#       male       age  cigsPerDay    BPMeds  prevalentStroke  prevalentHyp  \
# 0        1 -1.491940   -0.802371 -0.235345                0             0
# 1        0 -0.636581   -0.802371 -0.235345                0             0
# 2        1 -0.392192    0.872022 -0.235345                0             0
# 3        0  1.196332    1.709218 -0.235345                0             1
# 4        0 -0.636581    1.123181 -0.235345                0             0
# ...    ...       ...         ...       ...              ...           ...
# 7133     1 -0.392192    0.293313 -0.235345                0             0
# 7134     0  0.829749   -0.802371 -0.235345                0             1
# 7135     1 -1.491940    0.583318 -0.235345                0             0
# 7136     0  0.585361   -0.802371 -0.235345                0             0
# 7137     0  0.707555   -0.802371 -0.235345                0             1
#
#       diabetes   totChol     sysBP     diaBP       BMI  heartRate   glucose
# 0            0 -0.999691 -1.291367 -1.176209  0.226256   0.338382 -0.241270
# 1            0  0.232903 -0.656801 -0.288288  0.670725   1.636868 -0.273778
# 2            0  0.120849 -0.381822 -0.369008 -0.185383  -0.094446 -0.468828
# 3            0 -0.327367  0.570027  0.841794  0.632844  -0.960104  0.603947
# 4            0  1.017282 -0.276061 -0.046127 -0.751072   0.771211  0.018797
# ...        ...       ...       ...       ...       ...        ...       ...
# 7133         0 -1.258396 -0.409213  0.209051  0.672065  -1.498648 -0.273330
# 7134         0  0.990995  2.487447 -0.798353  0.051262  -0.381285 -0.176078
# 7135         0 -0.142674 -0.753098 -0.686355  1.117537   0.935419  0.447036
# 7136         0  0.076328 -0.762986 -0.812159 -0.218306  -1.175070 -0.080033
# 7137         0  1.051783  2.265968  2.056188  0.026050   0.617241 -0.020329
#
# [7138 rows x 13 columns]

# %%
from sklearn.model_selection import cross_val_score
knn_scores = []
for k in range(1,21):
    knn_classifier = KNeighborsClassifier(n_neighbors = k)
    score=cross_val_score(knn_classifier,X,Y,cv=10)
    knn_scores.append(score.mean())

# %%
plt.plot([k for k in range(1, 21)], knn_scores, color = 'red')
for i in range(1,21):
    plt.text(i, knn_scores[i-1], (i, knn_scores[i-1]))
plt.xticks([i for i in range(1, 21)])
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Scores')
plt.title('K Neighbors Classifier scores for different K values')
# Out:
# Text(0.5, 1.0, 'K Neighbors Classifier scores for different K values')

# %%
knn_classifier = KNeighborsClassifier(n_neighbors = k)
score=cross_val_score(knn_classifier,X,Y,cv=10)
knn_scores.append(score.mean())
knn_scores
# Out:
# [0.8535980451086467,
#  0.8639688694552156,
#  0.8194182862485807,
#  0.8295066413662239,
#  0.8028861755080714,
#  0.8117140264240339,
#  0.7894396187647571,
#  0.7971430928612679,
#  0.7787924145815408,
#  0.7883174026974042,
#  0.7702489972145941,
#  0.7751499758388629,
#  0.7604405577097599,
#  0.7653415363340287,
#  0.7527325656770423,
#  0.7552557348325024,
#  0.7460086980093581,
#  0.7521721451553974,
#  0.7415265124282533,
#  0.745311364377448,
#  0.745311364377448]

# %%
knn_classifier = KNeighborsClassifier(n_neighbors = 16)
score=cross_val_score(knn_classifier,X,Y,cv=10)
score.mean()
# Out:
# 0.7552557348325024

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
randomforest_classifier= RandomForestClassifier(n_estimators=10)

score=cross_val_score(randomforest_classifier,X,Y,cv=10)

# %%
score.mean()
# Out:
# 0.8573876114260571

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=10)
x_train
# Out:
#       male       age  cigsPerDay    BPMeds  prevalentStroke  prevalentHyp  \
# 5649     0  0.096584    0.505188 -0.235345                0             1
# 801      1 -0.269998   -0.551212 -0.235345                0             0
# 5860     0 -0.025610   -0.802371 -0.235345                0             1
# 3982     1 -1.491940   -0.048894 -0.235345                0             0
# 3592     0 -1.369746   -0.048894 -0.235345                0             0
# ...    ...       ...         ...       ...              ...           ...
# 1180     0  1.562914   -0.551212 -0.235345                0             0
# 3441     1  1.074138    1.709218 -0.235345                0             0
# 1344     1  1.562914    1.709218 -0.235345                0             0
# 4623     1  1.074138   -0.771628 -0.235345                0             1
# 1289     0 -0.147804   -0.802371 -0.235345                0             1
#
#       diabetes   totChol     sysBP     diaBP       BMI  heartRate   glucose
# 5649         0  2.069674  1.036687  1.490910 -0.316006   0.503466 -0.066000
# 801          0 -0.461831 -0.276061 -0.207568 -0.435397  -1.392933 -0.631370
# 5860         0 -0.047511  1.117621  1.300712  0.296696  -0.094446 -0.254950
# 3982         0  0.703530 -0.783714 -0.853329 -0.862189   0.251816 -0.273778
# 3592         0 -1.335853 -0.783714  0.155673 -0.854613   1.117474 -0.566353
# ...        ...       ...       ...       ...       ...        ...       ...
# 1180         0  1.689606 -0.064539 -0.369008 -0.213163   2.329394  0.148830
# 3441         0  0.188082 -0.064539  0.034593 -0.761173   0.338382 -0.761404
# 1344         0 -1.223799 -0.952932 -0.934049  2.135454  -0.094446  0.408897
# 4623         0 -0.441890  1.309578  2.049633  1.043523   1.219934 -0.028037
# 1289         0  0.008795  1.119985  1.648996  1.337429   1.117474 -0.306287
#
# [5710 rows x 13 columns]

# %%
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.7149859943977591

# %%
from sklearn import linear_model
reg=linear_model.LogisticRegression()
reg.fit(x_train,y_train)
reg.score(x_test,y_test)
#reg.predict(x_test)
# Out:
# 0.6519607843137255

# %%
clf=RandomForestClassifier(n_estimators = 100) 
clf.fit(x_train, y_train)
clf.score(x_test,y_test)
#clf.predict(x_test)
# Out:
# 0.8788515406162465

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
clf.fit(x_train,y_train)
predict = clf.predict(x_test)

# %%
print('\n')
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       701
#            1       0.88      0.90      0.89       727
#
#     accuracy                           0.89      1428
#    macro avg       0.89      0.89      0.89      1428
# weighted avg       0.89      0.89      0.89      1428

# %%
def Heart_disease(male,age,cigsPerDay,BPMeds,prevalentStroke,prevalentHyp,diabetes,totChol,sysBP,diaBP,BMI,heartRate,glucose):
    a=np.zeros(len(X.columns))
    a[0]=male
    a[1]=age
    a[2]=cigsPerDay
    a[3]=BPMeds
    a[4]=prevalentStroke
    a[5]=prevalentHyp
    a[6]=diabetes
    a[7]=totChol
    a[8]=sysBP
    a[9]=diaBP
    a[10]=BMI
    a[11]=heartRate
    a[12]=glucose
    return clf.predict([a])

# %%
Heart_disease(1,-1.491940,-0.048894,-0.235345,0,0,0,0.703530,-0.783714,-0.853329,-0.862189,0.251816,-0.273778)
# Out:
# array([0], dtype=int64)

# %%
Heart_disease(0,0.096584,0.505188,-0.235345,0,1,0,2.069674,1.036687,1.490910,-0.316006,0.503466,-0.066000)
# Out:
# array([1], dtype=int64)

# %%
Heart_disease(0,-0.025610,-0.802371,-0.235345,0,1,0,-0.047511,1.117621,1.300712,0.296696,-0.094446,-0.254950)
# Out:
# array([1], dtype=int64)

# %%
Heart_disease(1,0.463167,0.734407,-0.235345,0,0,0,-0.573885,-0.170300,0.074953,0.802046,-0.527275,0.603947)
# Out:
# array([0], dtype=int64)

# %%
Heart_disease(0,0.585361,-0.802371,-0.235345,0,0,0,0.905228,-1.502889,-1.095489,0.541930,0.251816,-0.566353)
# Out:
# array([0], dtype=int64)

# %%
Heart_disease(0,0.096584,0.505188,-0.235345,0,1,0,2.069674,1.036687,1.490910,-0.316006,0.503466,-0.066000)
# Out:
# array([1], dtype=int64)

# %%
Heart_disease(1,-0.269998,-0.551212,-0.235345,0,0,0,-0.461831,-0.276061,-0.207568,-0.435397,-1.392933,-0.631370)
# Out:
# array([0], dtype=int64)

# %%
x_train
# Out:
#       male       age  cigsPerDay    BPMeds  prevalentStroke  prevalentHyp  \
# 5649     0  0.096584    0.505188 -0.235345                0             1
# 801      1 -0.269998   -0.551212 -0.235345                0             0
# 5860     0 -0.025610   -0.802371 -0.235345                0             1
# 3982     1 -1.491940   -0.048894 -0.235345                0             0
# 3592     0 -1.369746   -0.048894 -0.235345                0             0
# ...    ...       ...         ...       ...              ...           ...
# 1180     0  1.562914   -0.551212 -0.235345                0             0
# 3441     1  1.074138    1.709218 -0.235345                0             0
# 1344     1  1.562914    1.709218 -0.235345                0             0
# 4623     1  1.074138   -0.771628 -0.235345                0             1
# 1289     0 -0.147804   -0.802371 -0.235345                0             1
#
#       diabetes   totChol     sysBP     diaBP       BMI  heartRate   glucose
# 5649         0  2.069674  1.036687  1.490910 -0.316006   0.503466 -0.066000
# 801          0 -0.461831 -0.276061 -0.207568 -0.435397  -1.392933 -0.631370
# 5860         0 -0.047511  1.117621  1.300712  0.296696  -0.094446 -0.254950
# 3982         0  0.703530 -0.783714 -0.853329 -0.862189   0.251816 -0.273778
# 3592         0 -1.335853 -0.783714  0.155673 -0.854613   1.117474 -0.566353
# ...        ...       ...       ...       ...       ...        ...       ...
# 1180         0  1.689606 -0.064539 -0.369008 -0.213163   2.329394  0.148830
# 3441         0  0.188082 -0.064539  0.034593 -0.761173   0.338382 -0.761404
# 1344         0 -1.223799 -0.952932 -0.934049  2.135454  -0.094446  0.408897
# 4623         0 -0.441890  1.309578  2.049633  1.043523   1.219934 -0.028037
# 1289         0  0.008795  1.119985  1.648996  1.337429   1.117474 -0.306287
#
# [5710 rows x 13 columns]

# %%
y_train
# Out:
# 5649    1
# 801     0
# 5860    1
# 3982    0
# 3592    0
#        ..
# 1180    0
# 3441    0
# 1344    0
# 4623    1
# 1289    0
# Name: TenYearCHD, Length: 5710, dtype: int64

# %%
import pickle
with open("Heart_disease_prediction.pickle",'wb') as f:
    pickle.dump(clf,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open('columns.json','w') as f:
    f.write(json.dumps(columns))
