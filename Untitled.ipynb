# %%
#importing the module
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.cm import rainbow
from matplotlib.cm import rainbow
from sklearn.model_selection import train_test_split

# %%
#importing the dataset
data=pd.read_csv('framingham.csv')
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4240 non-null   int64
#  1   age              4240 non-null   int64
#  2   education        4135 non-null   float64
#  3   currentSmoker    4240 non-null   int64
#  4   cigsPerDay       4211 non-null   float64
#  5   BPMeds           4187 non-null   float64
#  6   prevalentStroke  4240 non-null   int64
#  7   prevalentHyp     4240 non-null   int64
#  8   diabetes         4240 non-null   int64
#  9   totChol          4190 non-null   float64
#  10  sysBP            4240 non-null   float64
#  11  diaBP            4240 non-null   float64
#  12  BMI              4221 non-null   float64
#  13  heartRate        4239 non-null   float64
#  14  glucose          3852 non-null   float64
#  15  TenYearCHD       4240 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
data.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4240.000000  4240.000000  4135.000000    4240.000000  4211.000000
# mean      0.429245    49.580189     1.979444       0.494104     9.005937
# std       0.495027     8.572942     1.019791       0.500024    11.922462
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4187.000000      4240.000000   4240.000000  4240.000000  4190.000000
# mean      0.029615         0.005896      0.310613     0.025708   236.699523
# std       0.169544         0.076569      0.462799     0.158280    44.591284
# ...

# %% [markdown]
# ## Feature Selection

# %%
import seaborn as sns
#checking corelation between each feature using corr function
cormat=data.corr()
top_corr_features=cormat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'male'}>,
#         <AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'education'}>,
#         <AxesSubplot:title={'center':'currentSmoker'}>],
#        [<AxesSubplot:title={'center':'cigsPerDay'}>,
#         <AxesSubplot:title={'center':'BPMeds'}>,
#         <AxesSubplot:title={'center':'prevalentStroke'}>,
#         <AxesSubplot:title={'center':'prevalentHyp'}>],
#        [<AxesSubplot:title={'center':'diabetes'}>,
#         <AxesSubplot:title={'center':'totChol'}>,
#         <AxesSubplot:title={'center':'sysBP'}>,
#         <AxesSubplot:title={'center':'diaBP'}>],
#        [<AxesSubplot:title={'center':'BMI'}>,
#         <AxesSubplot:title={'center':'heartRate'}>,
#         <AxesSubplot:title={'center':'glucose'}>,
#         <AxesSubplot:title={'center':'TenYearCHD'}>]], dtype=object)

# %% [markdown]
# # splitting dataset

# %%
#Create independent and Dependent Features
columns = data.columns.tolist()
# Filter the columns to remove data we do not want 
columns = [c for c in columns if c not in ["TenYearCHD"]]
# Store the variable we are predicting 
target = "TenYearCHD"
# Define a random state 
state = np.random.RandomState(42)
x= data[columns]
y = data[target]
# Print the shapes of X & Y
print(x.shape)
print(y.shape)
# Out:
# (4240, 15)
# (4240,)

# %% [markdown]
# # filling up null values

# %%
x.isnull().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# dtype: int64

# %%
y.isnull().sum()
# Out:
# 0

# %%
x['cigsPerDay'].fillna(x.groupby('currentSmoker')['cigsPerDay'].transform('mean'),inplace=True)
x['BPMeds'].fillna(x.groupby('prevalentHyp')['BPMeds'].transform('median'),inplace=True)
x['totChol'].fillna(x.groupby('prevalentStroke')['totChol'].transform('mean'),inplace=True)
x['BMI'].fillna(x.groupby('age')['BMI'].transform('mean'),inplace=True)
x['heartRate'].fillna(x.groupby('sysBP')['heartRate'].transform('mean'),inplace=True)
x['glucose'].fillna(x.groupby('diabetes')['glucose'].transform('mean'),inplace=True)
x['education'].fillna(x.groupby('age')['education'].transform('mean'),inplace=True)
# Out:
# C:\Users\saurav aditya\anaconda3\envs\tensorflo\lib\site-packages\pandas\core\series.py:4469: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
x.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# dtype: int64

# %% [markdown]
# # Balance Dataset

# %%
sns.set_style('whitegrid')
sns.countplot(x ='TenYearCHD',data=data,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='TenYearCHD', ylabel='count'>

# %%
disease= data[data['TenYearCHD']==1]
no= data[data['TenYearCHD']==0]
print(disease.shape,no.shape)
# Out:
# (644, 16) (3596, 16)

# %%
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import NearMiss

# %%
smk=SMOTETomek(random_state=42)
x_res,y_res=smk.fit_resample(x,y)
x_res.shape,y_res.shape
# Out:
# ((7138, 15), (7138,))

# %%
from collections import Counter
print('original data {}'.format(Counter(y)))
print('Resampled data {}'.format(Counter(y_res)))
# Out:
# original data Counter({0: 3596, 1: 644})
# Resampled data Counter({0: 3569, 1: 3569})

# %%
#from sklearn.preprocessing import StandardScaler
#standardScaler = StandardScaler()
#columns_to_scale =['age','BPMeds','cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose']
#x_res[columns_to_scale] = standardScaler.fit_transform(x_res[columns_to_scale])

# %%
x_res
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39   4.000000              0    0.000000     0.0
# 1        0   46   2.000000              0    0.000000     0.0
# 2        1   48   1.000000              1   20.000000     0.0
# 3        0   61   3.000000              1   30.000000     0.0
# 4        0   46   3.000000              1   23.000000     0.0
# ...    ...  ...        ...            ...         ...     ...
# 7133     1   48   3.073740              1   13.087533     0.0
# 7134     0   58   1.000000              0    0.000000     0.0
# 7135     1   39   3.379383              1   16.551542     0.0
# 7136     0   56   1.000000              0    0.000000     0.0
# 7137     0   57   2.000000              0    0.000000     0.0
#
#       prevalentStroke  prevalentHyp  diabetes     totChol       sysBP  \
# 0                   0             0         0  195.000000  106.000000
# 1                   0             0         0  250.000000  121.000000
# ...

# %%
x_res.isnull().sum()
# Out:
# male               0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# dtype: int64

# %% [markdown]
# # Different Classifiers

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
X=x_res.drop(['education','currentSmoker'],axis=1)
Y=y_res
X=X.astype({"cigsPerDay":'int', "BPMeds":'int',"prevalentStroke":'int',"prevalentHyp":'int',"diabetes":'int',"totChol":'int',"sysBP":'int',"diaBP":'int',"BMI":'int',"heartRate":'int',"glucose":'int'}) 
#Y=Y.astype({"cigsPerDay":'int', "BPMeds":'int',"prevalentStroke":'int',"prevalentHyp":'int',"diabetes":'int',"totChol":'int',"sysBP":'int',"diaBP":'int',"BMI":'int',"heartRate":'int',"glucose":'int'})
X
# Out:
#       male  age  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  diabetes  \
# 0        1   39           0       0                0             0         0
# 1        0   46           0       0                0             0         0
# 2        1   48          20       0                0             0         0
# 3        0   61          30       0                0             1         0
# 4        0   46          23       0                0             0         0
# ...    ...  ...         ...     ...              ...           ...       ...
# 7133     1   48          13       0                0             0         0
# 7134     0   58           0       0                0             1         0
# 7135     1   39          16       0                0             0         0
# 7136     0   56           0       0                0             0         0
# 7137     0   57           0       0                0             1         0
#
# ...

# %%
from sklearn.model_selection import cross_val_score
knn_scores = []
for k in range(1,21):
    knn_classifier = KNeighborsClassifier(n_neighbors = k)
    score=cross_val_score(knn_classifier,X,Y,cv=10)
    knn_scores.append(score.mean())

# %%
plt.plot([k for k in range(1, 21)], knn_scores, color = 'red')
for i in range(1,21):
    plt.text(i, knn_scores[i-1], (i, knn_scores[i-1]))
plt.xticks([i for i in range(1, 21)])
plt.xlabel('Number of Neighbors (K)')
plt.ylabel('Scores')
plt.title('K Neighbors Classifier scores for different K values')
# Out:
# Text(0.5, 1.0, 'K Neighbors Classifier scores for different K values')

# %%
knn_classifier = KNeighborsClassifier(n_neighbors = k)
score=cross_val_score(knn_classifier,X,Y,cv=10)
knn_scores.append(score.mean())
knn_scores
# Out:
# [0.8825980883236886,
#  0.8950693601423738,
#  0.8458939817161086,
#  0.8579425318514502,
#  0.8139527620304783,
#  0.8290837232508711,
#  0.8003628099206022,
#  0.8091892858125018,
#  0.7849523259514186,
#  0.7947591940001808,
#  0.7759867761971548,
#  0.7839721302265648,
#  0.7659001889675927,
#  0.7766882349012537,
#  0.765058281377067,
#  0.768140692462118,
#  0.753712368537878,
#  0.7593159844582994,
#  0.7471283604605938,
#  0.7527313870849882,
#  0.7527313870849882]

# %%
knn_classifier = KNeighborsClassifier(n_neighbors = 16)
score=cross_val_score(knn_classifier,X,Y,cv=10)
score.mean()
# Out:
# 0.768140692462118

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
randomforest_classifier= RandomForestClassifier(n_estimators=10)

score=cross_val_score(randomforest_classifier,X,Y,cv=10)

# %%
score.mean()
# Out:
# 0.8477207993997039

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=10)
x_train
# Out:
#       male  age  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  diabetes  \
# 5649     0   52          15       0                0             1         0
# 801      1   49           3       0                0             0         0
# 5860     0   51           0       0                0             1         0
# 3982     1   39           9       0                0             0         0
# 3592     0   40           9       0                0             0         0
# ...    ...  ...         ...     ...              ...           ...       ...
# 1180     0   64           3       0                0             0         0
# 3441     1   60          30       0                0             0         0
# 1344     1   64          30       0                0             0         0
# 4623     1   60           0       0                0             1         0
# 1289     0   50           0       0                0             1         0
#
# ...

# %%
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.6568627450980392

# %%
from sklearn import linear_model
reg=linear_model.LogisticRegression()
reg.fit(x_train,y_train)
reg.score(x_test,y_test)
#reg.predict(x_test)
# Out:
# C:\Users\saurav aditya\anaconda3\envs\tensorflo\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.5994397759103641

# %%
clf=RandomForestClassifier(n_estimators = 100) 
clf.fit(x_train, y_train)
clf.score(x_test,y_test)
#clf.predict(x_test)
# Out:
# 0.8760504201680672

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
clf.fit(x_train,y_train)
predict = clf.predict(x_test)

# %%
print('\n')
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.87       701
#            1       0.87      0.90      0.88       727
#
#     accuracy                           0.88      1428
#    macro avg       0.88      0.88      0.88      1428
# weighted avg       0.88      0.88      0.88      1428

# %%
def Heart_disease(male,age,cigsPerDay,BPMeds,prevalentStroke,prevalentHyp,diabetes,totChol,sysBP,diaBP,BMI,heartRate,glucose):
    a=np.zeros(len(X.columns),dtype=int)
    a[0]=male
    a[1]=age
    a[2]=cigsPerDay
    a[3]=BPMeds
    a[4]=prevalentStroke
    a[5]=prevalentHyp
    a[6]=diabetes
    a[7]=totChol
    a[8]=sysBP
    a[9]=diaBP
    a[10]=BMI
    a[11]=heartRate
    a[12]=glucose
    #vector = np.vectorize(np.float)
    #x = vector(a)
    #k=a.reshape(2,3)
    return clf.predict([a])[0]

# %% [markdown]
# # Training of train data set

# %%
print(type(Heart_disease(1,49,3,0,0,0,0,219,130,82,24,60,65)))
# Out:
# <class 'numpy.int64'>

# %%
Heart_disease(0,51,0,0,0,1,0,237,162,100,27,75,76)
# Out:
# 1

# %% [markdown]
# # Testing of test data

# %%
Heart_disease(0,47,0,0,0,1,0,248,143,109,32,76,66)
# Out:
# 0

# %%
Heart_disease(0,45,17,0,0,0,0,310,117,76,27,67,64)
# Out:
# 1

# %%
x_test
# Out:
#       male  age  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  diabetes  \
# 1492     1   55          18       0                0             0         0
# 4336     0   45          17       0                0             0         0
# 2756     0   56           0       0                0             0         0
# 1651     0   47           0       0                0             1         0
# 1729     0   38           0       0                0             0         0
# ...    ...  ...         ...     ...              ...           ...       ...
# 3828     0   46           0       0                0             0         0
# 3246     1   44          20       0                0             1         0
# 2950     0   49          20       1                0             1         0
# 17       0   46          20       0                0             0         0
# 2515     0   41           0       0                0             1         0
#
# ...

# %%
y_test
# Out:
# 1492    0
# 4336    1
# 2756    0
# 1651    0
# 1729    0
#        ..
# 3828    0
# 3246    0
# 2950    0
# 17      1
# 2515    0
# Name: TenYearCHD, Length: 1428, dtype: int64

# %%
import pickle
with open("Heart_disease_prediction.pickle",'wb') as f:
    pickle.dump(clf,f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns.tolist()]
}
np.asarray(columns["data_columns"])
with open('columns.json','w') as f:
    f.write(json.dumps(columns))
